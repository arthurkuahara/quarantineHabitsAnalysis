# %%
import pandas as pd
from pytrends.request import TrendReq

pytrend = TrendReq(hl='en-US', tz=360)
keywords = ['tiktok', 'covid-19']
pytrend.build_payload(
     kw_list=keywords,
     cat=0,
     timeframe='today 12-m',
     geo='TW',
     gprop='')
data = pytrend.interest_over_time()
data= data.drop(labels=['isPartial'],axis='columns')
image = data.plot(title = 'TikTok vs Facebook')
fig = image.get_figure()
fig.savefig('figure_tiktok.png')
data.to_csv('tiktok.csv', encoding='utf_8_sig')

# %%
sum_70 = 226
sum_21 = 249

# %%
import matplotlib.pyplot as plt
from pylab import *

labels = ['Jan 5 - Mar 14 (70 days)', 'Mar 15 - Apr 4 (21 days)']
sizes = [sum_70, sum_21]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Number of searches for "Nintendo Switch" in 2020, in Google Trends Popularity Units')



plt.show()
